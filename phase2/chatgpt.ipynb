# %%
## Randomly Retreive each set
import torch
from torch.utils.data import Dataset
import random
import pandas as pd
import random
import numpy as np
import torch
from sklearn.model_selection import KFold, StratifiedKFold
import os
from transformers import AutoModelForSequenceClassification, AutoTokenizer, RobertaForSequenceClassification, AutoModel
import torch.nn as nn
from transformers import PreTrainedModel
from transformers.modeling_outputs import TokenClassifierOutput

from torch.utils.data import DataLoader
from transformers import DataCollatorWithPadding


from tqdm.auto import tqdm
from torch.optim.lr_scheduler import LambdaLR

import json
import openai

# https://ddnews.co.kr/mbti-%EC%A7%88%EB%AC%B8-%EB%A6%AC%EC%8A%A4%ED%8A%B8/ 13, 16, 17, 14
q_category = [0, 1, 2, 3, 2, 0, 3, 2, 3, 2, 0, 1, 2, 3, 0, 0, 1, 2, 1, 3, 0, 1, 2, 3, 2, 0, 2, 1, 3, 1, 0, 1, 2, 3, 1, 0, 1, 2, 3, 1, 0, 2, 0, 3, 1, 1, 2, 2, 3, 1, 0, 1, 0, 2, 1, 3, 2, 2, 3, 3]

questions= """주기적으로 새로운 친구를 만든다.
자유 시간 중 상당 부분을 다양한 관심사를 탐구하는 데 할애한다.
다른 사람이 울고 있는 모습을 보면 자신도 울고 싶어질 때가 많다.
일이 잘못될 때를 대비해 여러 대비책을 세우는 편이다.
압박감이 심한 환경에서도 평정심을 유지하는 편이다.
파티나 행사에서 새로운 사람에게 먼저 자신을 소개하기보다는 주로 이미 알고 있는 사람과 대화하는 편이다.
하나의 프로젝트를 완전히 완료한 후 다른 프로젝트를 시작하는 편이다.
매우 감상적인 편이다.
일정이나 목록으로 계획을 세우는 일을 좋아한다.
작은 실수로도 자신의 능력이나 지식을 의심하곤 한다.
관심이 가는 사람에게 다가가서 대화를 시작하기가 어렵지 않다.
예술 작품의 다양한 해석에 대해 토론하는 일에는 크게 관심이 없다.
감정보다는 이성을 따르는 편이다.
하루 일정을 계획하기보다는 즉흥적으로 하고 싶은 일을 하는 것을 좋아한다.
다른 사람에게 자신이 어떤 사람으로 보일지 걱정하지 않는 편이다.
단체 활동에 참여하는 일을 즐긴다.
결말을 자신의 방식으로 해석할 수 있는 책과 영화를 좋아한다.
자신보다는 남의 성공을 돕는 일에서 더 큰 만족감을 느낀다.
관심사가 너무 많아 다음에 어떤 일을 해야 할지 모를 때가 있다.
일이 잘못될까봐 자주 걱정하는 편이다.
단체에서 지도자 역할을 맡는 일은 가능한 피하고 싶다.
자신에게 예술적 성향이 거의 없다고 생각한다.
사람들이 감정보다는 이성을 중시했다면 더 나은 세상이 되었으리라고 생각한다.
휴식을 취하기 전에 집안일을 먼저 끝내기를 원한다.
다른 사람의 논쟁을 바라보는 일이 즐겁다.
다른 사람의 주의를 끌지 않으려고 하는 편이다.
감정이 매우 빠르게 변하곤 한다.
자신만큼 효율적이지 못한 사람을 보면 짜증이 난다.
해야 할 일을 마지막까지 미룰 때가 많다.
사후세계에 대한 질문이 흥미롭다고 생각한다.
혼자보다는 다른 사람과 시간을 보내고 싶어한다.
이론 중심의 토론에는 관심이 없으며 원론적인 이야기는 지루하다고 생각한다.
자신과 배경이 완전히 다른 사람에게도 쉽게 공감할 수 있다.
결정을 내리는 일을 마지막까지 미루는 편이다.
이미 내린 결정에 대해서는 다시 생각하지 않는 편이다.
혼자만의 시간을 보내기보다는 즐거운 파티와 행사로 일주일의 피로를 푸는 편이다.
미술관에 가는 일을 좋아한다.
다른 사람의 감정을 이해하기 힘들 때가 많다.
매일 할 일을 계획하는 일을 좋아한다.
불안함을 느낄 때가 거의 없다.
전화 통화를 거는 일은 가능한 피하고 싶다.
자신의 의견과 매우 다른 의견을 이해하기 위해 많은 시간을 할애하곤 한다.
친구에게 먼저 만나자고 연락하는 편이다.
계획에 차질이 생기면 최대한 빨리 계획으로 돌아가기 위해 노력한다.
오래전의 실수를 후회할 때가 많다.
인간의 존재와 삶의 이유에 대해 깊이 생각하지 않는 편이다.
감정을 조절하기보다는 감정에 휘둘리는 편이다.
상대방의 잘못이라는 것이 명백할 때도 상대방의 체면을 살려주기 위해 노력한다.
계획에 따라 일관성 있게 업무를 진행하기보다는 즉흥적인 에너지로 업무를 몰아서 처리하는 편이다.
상대방이 자신을 높게 평가하면 나중에 상대방이 실망하게 될까 걱정하곤 한다.
대부분의 시간을 혼자서 일할 수 있는 직업을 원한다.
철학적인 질문에 대해 깊게 생각하는 일은 시간 낭비라고 생각한다.
조용하고 사적인 장소보다는 사람들로 붐비고 떠들썩한 장소를 좋아한다.
상대방의 감정을 바로 알아차릴 수 있다.
무엇인가에 압도당하는 기분을 느낄 때가 많다.
단계를 건너뛰는 일 없이 절차대로 일을 완수하는 편이다.
논란이 되거나 논쟁을 불러일으킬 수 있는 주제에 관심이 많다.
자신보다 다른 사람에게 더 필요한 기회라고 생각되면 기회를 포기할 수도 있다.
마감 기한을 지키기가 힘들다.
일이 원하는 대로 진행될 것이라는 자신감이 있다.""".split("\n")

# FIX RANDOM SEED
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def call_gpt(prompt):
    received = False 
    response = None

    while not received:
        try:
            response = openai.ChatCompletion.create(
                        model="gpt-3.5-turbo",
                        messages = [{"role": "user", "content": prompt}],
                        #   prompt=source,
                        temperature=0,
                        max_tokens=128,
                        top_p=1,
                        frequency_penalty=0,
                        presence_penalty=0,
                        stop=["\n\n"]
                    )
            received = True
        except:
            import sys, time
            error = sys.exc_info()[0]
            if error == openai.error.InvalidRequestError: 
                # something is wrong: e.g. prompt too long
                print(f"InvalidRequestError\nPrompt passed in:\n\n{prompt}\n\n")
                assert False
            print("API error:", error)
            time.sleep(2)

    return response

openai.api_key = "" # Fill it here.

def convert_MBTI(x):
    tmp = "ISTJ"
    return [0 if letter in tmp else 1 for letter in x]


class ClfModel(nn.Module):
    def __init__(self, name_or_path, out_size=1024):
        super(ClfModel, self).__init__()
        self.model = AutoModel.from_pretrained(name_or_path)
        self.out = out_size
        
        self.nn_1 = nn.Sequential(
         nn.Dropout(p=0.1),
         nn.Linear(self.out, 1)
        )
    
    def forward(self, input_ids, attention_mask, **kwargs):
        out = self.model(input_ids=input_ids, attention_mask=attention_mask)['last_hidden_state'][:, 0, :] # select first token.
        out1 = self.nn_1(out)

        return out1

def collate_fn(batch):
    input_ids = []
    attention_mask = []
    token_type_ids = []
    labels = []

    # Pad all sequences to the same length
    max_len = max([x['input_ids'].size(1) for x in batch])

    for x in batch:
        input_ids.append(torch.nn.functional.pad(x['input_ids'], (0, max_len - x['input_ids'].size(1)), value=0))
        attention_mask.append(torch.nn.functional.pad(x['attention_mask'], (0, max_len - x['attention_mask'].size(1)), value=0))
        token_type_ids.append(torch.nn.functional.pad(x['token_type_ids'], (0, max_len - x['token_type_ids'].size(1)), value=0))
        labels.append(x['label'])

    # Stack padded sequences into tensors
    input_ids = torch.stack(input_ids).squeeze()
    attention_mask = torch.stack(attention_mask).squeeze()
    token_type_ids = torch.stack(token_type_ids).squeeze()
    labels = torch.stack(labels).squeeze()
    
    return {'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids, 'labels': labels}


def get_acc(preds, labels, threshold=0.5, show_result=False):

    sig = nn.Sigmoid()

    with torch.no_grad():
        new_preds = sig(preds)  
    
    new_preds = new_preds.detach().cpu().numpy()
    labels = labels.detach().cpu().numpy()

    binary_preds = (new_preds >= threshold).astype(np.float32)

    # Compute accuracy using the binary predictions and true targets
    # correct_preds = (binary_preds == labels).all(axis=1).astype(np.float32)
    # strong_accuracy = correct_preds.sum() / len(labels)

    weak_preds = (binary_preds == labels).mean().astype(np.float32)
    # weak_accuracy = weak_preds.sum() / len(labels)

    if show_result:
        return weak_preds, binary_preds
    
    return weak_preds.item()



def run(THIS_IDX):

    class MBTIDataset(Dataset):
        def __init__(self, df, tokenizer, mode="Train"):
            self.df = df
            self.tokenizer = tokenizer
            self.users = self.df.User_ID.unique()

            self.mode = mode

        def __len__(self):
            return len(self.users)

        def __getitem__(self, idx):
                
            user_id = self.users[idx]
            user_data = self.df[self.df.User_ID == user_id]
            chosen = user_data.sample(n=N, replace=False, random_state=None)
            
            tmp = chosen['Final_Answer'].tolist()
            
            random.shuffle(tmp)
            text = ' '.join(tmp)
            
            label = chosen['MBTI'].unique()[0][THIS_IDX]

            return text, label


    ### MAIN CODE ### 
    main_df = pd.read_csv("/workspace/final_QIA/merged_train.csv")
    test_df = pd.read_csv("/workspace/final_QIA/phase2/test.csv")
    # questions = pd.read_excel("/workspace/COMP/QIA/Question.xlsx")

    main_df['Answer'] = main_df['Short_Answer'] + " " + main_df['Long_Answer']
    main_df['Q_text'] = main_df['Q_number'].map(lambda x: questions[x-1])
    main_df['Final_Answer'] = main_df['Long_Answer']

    test_df['Answer'] = test_df['Short_Answer'] + " " + test_df['Long_Answer']
    test_df['Q_text'] = test_df['Q_number'].map(lambda x: questions[x-1])
    test_df['Final_Answer'] = test_df['Long_Answer']
    
    rseed = 42
    set_seed(rseed)

    tgt = list(main_df['User_ID'].unique())

    q_list = [i + 1 for i in range(60) if q_category[i] == THIS_IDX]
    mbtis = [main_df[main_df.User_ID == x].iloc[0]['MBTI'] for x in tgt]
    mbti_labels = [0 if x[THIS_IDX] in "ISTJ" else 1 for x in mbtis] 
    

    kf = StratifiedKFold(n_splits=3, shuffle=True, random_state=rseed)
    kf = [x for x in kf.split(tgt, mbti_labels)]

    # train = [tgt[i] for i in kf[0][0]] # only use the first seed. -> second seed
    # val =  [tgt[i] for i in kf[0][1]] # only use the first seed. -> second seed

    # # Set phase1 as train and phase2 as val
    train = list(range(1, 241))    
    val = list(range(241, 361))

    # from collections import Counter
    # a = Counter([mbti_labels[x] for x in kf[0][0]])
    # b = Counter([mbti_labels[x] for x in kf[0][1]])

    main_df = main_df[main_df.Q_number.isin(q_list)]
    test_df = test_df[test_df.Q_number.isin(q_list)]

    # Assign random MBTIs for test set.
    test_df['MBTI'] = test_df['Answer'].map(lambda x: "ISTJ")

    # # Separate Train and Valid
    train_df = main_df[main_df.User_ID.isin(train)]
    val_df = main_df[main_df.User_ID.isin(val)]

    N = 10

    model_name = "klue/roberta-large"
    model_path = f"/workspace/final_QIA/models_phase3/{model_name}"

    os.makedirs(model_path, exist_ok=True)

    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = ClfModel(model_name, out_size=1024)

    train_dataset = MBTIDataset(train_df, tokenizer)
    val_dataset = MBTIDataset(val_df, tokenizer)

    # test_dataset = MBTIDataset(test_df, tokenizer)
    # test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False, collate_fn=collate_fn)

    all_preds =  []
    all_labels = []

    for x in tqdm(val_dataset):
        msg, lbl = x
        inst = "Below you are given a series of responses used for MBTI test questions. Your task is to determine whether the user is more likely to be extroverted (E) or introverted (I). Generate answer only without producing any explanation.\n\n"
        final_msg = inst + msg + '\n\nAnswer: '
        out = call_gpt(final_msg)
        all_preds.append(out['choices'][0]['message']['content'])
        all_labels.append(lbl)


    import pdb
    pdb.set_trace()
    acc = sum([1 if x == y else 0 for x, y in zip([x.strip()[0] for x in all_preds], all_labels) ])


all_preds = []    


if __name__ == "__main__":
    for i in range(1):
        run(i)
# Out:
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/120 [00:00<?, ?it/s]
# > <ipython-input-9-4586162f03a3>(308)run()
#     306     import pdb
#     307     pdb.set_trace()
# --> 308     acc = sum([1 if x == y else 0 for x, y in zip([x.strip()[0] for x in all_preds], all_labels) ])
#     309
#     310
#
# 60
# ['I', 'I', 'I, I, I, E, I, I, I, E, I, E, I', 'I', 'E', 'I', 'I', 'I', 'I', 'I', 'I, I, E, I, I, I, E, I, I, I, I', 'I', 'E', 'I', 'I', 'I', 'I', 'I', 'E', 'I', 'I, I, I, E, I, I, I, I, I, I', 'I, I, E, E, I, I, I, E, I, I, I, I, E, E, I', 'E', 'E', 'I', 'I', 'I', 'I', 'E', 'E', 'I', 'I', 'I', 'E', 'E', 'I', 'E', 'I', 'I, I, I, I, I, I, E, I, I, I, I', 'I', 'I', 'I', 'I', 'I', 'I', 'E', 'I I I I I I I E I I I I I I I I I', 'I', 'I', 'I', 'I', 'I', 'E', 'I', 'I', 'E', 'I', 'E', 'I', 'E', 'I', 'I', 'I E E I I E E E E E', 'E', 'I', 'I', 'I', 'I', 'I', 'I, I, I, I, I, I, I/E, I, I, I, E, I, E, E, I', 'E', 'E', 'I', 'E (extroverted)', 'I', 'I', 'I, I, I, I, I, I, I, E, I, E', 'E', 'I', 'I', 'I', 'E', 'I', 'I', 'E', 'I', 'I, I, I, I, E, I, I, I, I, E', 'E', 'E', 'I', 'I, I, I, I, E, I, I, I, I, I, I, I, I, I', 'I', 'I', 'E', 'E', 'I', 'I', 'I', 'I', 'I', 'E, I, E, E, I, E, I, I, E, I', 'E (extroverted)', 'I', 'I', 'E', 'E', 'I', 'I', 'I', 'E', 'I', 'E', 'I, E, I, I, I, I, E, I, I, E, I', 'I, I, I, I, E, E, I, I, I, I, I, I, I', 'I', 'E, E, I, E, E, E, E, E, E', 'I', 'I', 'E', 'I']
# ('일을 수행하는 데 온전히 집중하고 싶습니다. 많은 사람과 함께 일하다 보면 사사롭고 불필요한 일에 신경 써야 할 때가 많은데 시간 낭비라고 생각합니다. 대부분의 상황에서는 다른 사람의 주의를 크게 끌지 않고 조용히 있으려고 하는 편이지만, 제가 관심 있는 사람이나 상황의 경우에는 주의를 끌기 위해 노력하기도 합니다. 나서는 것을 좋아하지는 않지만 필요에 따라 나에게 이득이 된다고 생각할 때에는 적극적으로 나서고 어필하는 성향입니다. 다른 사람과 함께 보내는 시간보다 나 혼자만의 시간을 좋아하고, 요즘은 직접적인 만남 없이도 충분히 안부를 주고받을 수 있어서 먼저 만나자고 연락하지는 않습니다. 새로운 사람을 만나서 이야기를 나누고 마음이 통하는 친구가 되기까지의 과정은 많은 에너지를 필요로 해서 피곤한 일입니다. 새 친구를 사귀기보다는 오랜 기간 알고 지낸 친구 만나는 것을 더 좋아합니다. 새로운 사람에게 나를 소개하는 일은 흥미로운 일인 동시에 굉장히 피곤한 일입니다. 나를 잘 포장해서 보여줘야 한다는 부담감과 더불어 새로운 사람을 만나고 사귀는 과정 자체가 귀찮고 피곤하기도 합니다. 이미 서로 알고 있는 사람과 대화하면 편하게 할 말만 하면 되니까 새로운 사람과의 대화보다 더 선호하는 것 같습니다. 외부 소리에 예민한 편이라 사람이 붐비고 떠들썩한 장소를 매우 싫어합니다. 어떻게 보면 제가 예측할 수 없는 환경에 노출되는 것이 싫습니다. 조용하고 사적인 장소에서 더 편안함을 느낍니다. 혼자 조용히 생각을 정리하고 할 일을 하는 것을 더 선호하는 편입니다. 관심 가는 사람이라면 먼저 다가가서 대화를 쉽게 할 수 있습니다. 다른 사람과 대화하는 것이 어려운 일은 아니지만 관심 없는 사람과의 대화를 시간 낭비라고 생각하는 경향이 있어 싫어할 뿐, 관심 있는 사람과의 대화는 즐겁습니다. 즉각적인 답변이 필요한 경우가 아니라면 요즘은 전화를 대체할 수 있는 수단이 많으므로 굳이 선호하지는 않습니다. 이메일이나 문자 등을 이용하면 기록도 남길 수 있어 좋습니다. 서로 다른 생각과 이해관계가 있는 사람들이 하나의 단체로 모여 같은 행동을 하는 것을 굉장히 싫어합니다. 단체보다는 개인을 선호합니다. 단체 조직 생활인 회사를 떠나 개인 프리랜서로 일을 하는 것도 같은 맥락입니다.', 'I')
# ('저는 혼자 있는 것을 좋아합니다. 사람들이 붐비고 떠들썩한 장소는 정신이 없어 보통 싫어합니다. 저는 저를 소개할 때도 있고 이미 알고 있는 사람과 이야기할 때도 있습니다. 보통 그곳의 분위기에 따라 달라지는 것 같습니다. 혼자서 일할 수 있는 직업을 원합니다. 혼자서 생각하며 일하는 것이 재미있기 때문입니다. 저는 다른 사람의 주의를 끌지 않으려고 합니다. 이유는 다른 사람이 저에 대해서 신경을 쓰는 것을 불편해하기 때문입니다. 다른 사람이 저를 어떻게 생각하는지 별로 신경 쓰지 않습니다. 20대에는 신경을 많이 쓰는 편이었으나 나이가 들어감에 따라 점점 신경을 쓰지 않게 되었습니다. 저는 주기적으로는 새로운 친구들을 만들지 않습니다. 이유는 새로운 친구들을 사기기 싫을 때도 있기 때문입니다. 혼자서 있는 것을 좋아합니다. 요즘에는 그래서 모임에 나간 적이 없습니다. 혼자 있는 것을 좋아하기 때문에 파티나 행사에 가는 것을 싫어합니다. 저는 관심이 가는 사람에게 다가가서 이야기를 먼저 거는 편입니다. 스스로가 인상이 좋은 편이라고 생각하기 때문에 먼저 쉽게 다가가는 편입니다. 아닙니다. 저는 혼자서 있는 것을 좋아하기 때문에 친구에게 먼저 연락을 잘하지 않습니다.', 'E')
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-9-4586162f03a3> in <module>
#     314 if __name__ == "__main__":
#     315     for i in range(1):
# --> 316         run(i)
#
# <ipython-input-9-4586162f03a3> in run(THIS_IDX)
#     306     import pdb
#     307     pdb.set_trace()
# --> 308     acc = sum([1 if x == y else 0 for x, y in zip([x.strip()[0] for x in all_preds], all_labels) ])
#     309
#     310
#
# <ipython-input-9-4586162f03a3> in run(THIS_IDX)
#     306     import pdb
#     307     pdb.set_trace()
# --> 308     acc = sum([1 if x == y else 0 for x, y in zip([x.strip()[0] for x in all_preds], all_labels) ])
#     309
#     310
#
# /opt/conda/lib/python3.8/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# /opt/conda/lib/python3.8/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
main_df = pd.read_csv("/workspace/final_QIA/merged_train.csv")

# %%
main_df[main_df.Long_Answer.str.contains("저는 혼자 있는 것을 좋아합니다. 사람들이 붐비고 떠들썩한 장소는 정신이 없어 보통 싫어합니다.")]
# Out:
#        User_ID  Gender  Age  MBTI  Q_number  \
# 11632      242       1   40  ENTJ        53
#
#                                                   Answer Short_Answer  \
# 11632  <아니다> 저는 혼자 있는 것을 좋아합니다. 사람들이 붐비고 떠들썩한 장소는 정신이...        <아니다>
#
#                                              Long_Answer
# 11632  저는 혼자 있는 것을 좋아합니다. 사람들이 붐비고 떠들썩한 장소는 정신이 없어 보통...

# %%
main_df[main_df.User_ID == 242]
# Out:
#        User_ID  Gender  Age  MBTI  Q_number  \
# 11580      242       1   40  ENTJ         1
# 11581      242       1   40  ENTJ         2
# 11582      242       1   40  ENTJ         3
# 11583      242       1   40  ENTJ         4
# 11584      242       1   40  ENTJ         5
# 11585      242       1   40  ENTJ         6
# 11586      242       1   40  ENTJ         7
# 11587      242       1   40  ENTJ         8
# 11588      242       1   40  ENTJ         9
# 11589      242       1   40  ENTJ        10
# 11590      242       1   40  ENTJ        11
# 11591      242       1   40  ENTJ        12
# 11592      242       1   40  ENTJ        13
# 11593      242       1   40  ENTJ        14
# 11594      242       1   40  ENTJ        15
# 11595      242       1   40  ENTJ        16
# 11596      242       1   40  ENTJ        17
# 11597      242       1   40  ENTJ        18
# 11598      242       1   40  ENTJ        19
# 11599      242       1   40  ENTJ        20
# 11600      242       1   40  ENTJ        21
# 11601      242       1   40  ENTJ        22
# 11602      242       1   40  ENTJ        23
# 11603      242       1   40  ENTJ        24
# 11604      242       1   40  ENTJ        25
# 11605      242       1   40  ENTJ        26
# 11606      242       1   40  ENTJ        27
# 11607      242       1   40  ENTJ        28
# 11608      242       1   40  ENTJ        29
# 11609      242       1   40  ENTJ        30
# 11610      242       1   40  ENTJ        31
# 11611      242       1   40  ENTJ        32
# 11612      242       1   40  ENTJ        33
# 11613      242       1   40  ENTJ        34
# 11614      242       1   40  ENTJ        35
# 11615      242       1   40  ENTJ        36
# 11616      242       1   40  ENTJ        37
# 11617      242       1   40  ENTJ        38
# 11618      242       1   40  ENTJ        39
# 11619      242       1   40  ENTJ        40
# 11620      242       1   40  ENTJ        41
# 11621      242       1   40  ENTJ        42
# 11622      242       1   40  ENTJ        43
# 11623      242       1   40  ENTJ        44
# 11624      242       1   40  ENTJ        45
# 11625      242       1   40  ENTJ        46
# 11626      242       1   40  ENTJ        47
# 11627      242       1   40  ENTJ        48
# 11628      242       1   40  ENTJ        49
# 11629      242       1   40  ENTJ        50
# 11630      242       1   40  ENTJ        51
# 11631      242       1   40  ENTJ        52
# 11632      242       1   40  ENTJ        53
# 11633      242       1   40  ENTJ        54
# 11634      242       1   40  ENTJ        55
# 11635      242       1   40  ENTJ        56
# 11636      242       1   40  ENTJ        57
# 11637      242       1   40  ENTJ        58
# 11638      242       1   40  ENTJ        59
# 11639      242       1   40  ENTJ        60
#
#                                                   Answer Short_Answer  \
# 11580  <중립> 저는 주기적으로는 새로운 친구들을 만들지 않습니다. 이유는 새로운 친구들을...         <중립>
# 11581  <그렇다> 자유 시간의 대부분을 관심사를 공부하는 데 씁니다. 요즘은 온라인 부업에...        <그렇다>
# 11582  <그렇다> 저는 다른 사람이 울고 있으면 같이 우는 편입니다. 울고 있는 사람의 슬...        <그렇다>
# 11583  <그렇다> 항상 여러 대비책을 세우는 편입니다. 이유는 계획과 달라졌을 때를 대비하...        <그렇다>
# 11584  <아니다> 저는 평정심을 유지하지 못합니다. 이유는 압박감이 없어도 스스로에게 엄격...        <아니다>
# 11585  <중립> 저는 저를 소개할 때도 있고 이미 알고 있는 사람과 이야기할 때도 있습니다...         <중립>
# 11586  <중립> 하나의 프로젝트를 완료하고 할 때도 있고 다른 프로젝트도 같이 할 때도 있...         <중립>
# 11587  <그렇다> 저는 감상적이라고 생각합니다. 혼자 슬픈 생각이 자주 떠올라 우수에 젖을...        <그렇다>
# 11588  <그렇다> 계획을 세우는 일을 좋아합니다. 보통 핸드폰 앱을 이용하여 계획을 항상 ...        <그렇다>
# 11589  <그렇다> 저는 작은 실수로도 제 능력을 의심합니다. 이유는 스스로에게 엄격하기 때...        <그렇다>
# 11590  <그렇다> 저는 관심이 가는 사람에게 다가가서 이야기를 먼저 거는 편입니다. 스스로...        <그렇다>
# 11591  <그렇다> 예술 작품은 해석을 토론하는 일은 관심이 없습니다. 제가 관심이 있는 분...        <그렇다>
# 11592  <그렇다> 저는 이성에 따라서 판단하는 것을 선호하는 편입니다. 그러나 주변 사람들...        <그렇다>
# 11593  <중립> 계획을 세워하는 것을 좋아할 때도 있고 즉흥적으로 하는 것을 좋아할 때도 ...         <중립>
# 11594  <그렇다> 다른 사람이 저를 어떻게 생각하는지 별로 신경 쓰지 않습니다. 20대에는...        <그렇다>
# 11595  <아니다> 저는 단체 활동하는 것을 좋아하지 않습니다. 요즘에는 그래서 대부분의 시...        <아니다>
# 11596  <아니다> 저는 다양한 해석이 나올 수 있는 결말을 별로 좋아하지 않습니다. 명쾌한...        <아니다>
# 11597  <아니다> 제 자신이 더 중요하다고 생각합니다. 제 자신에게서 더 큰 만족감을 느끼...        <아니다>
# 11598  <아니다> 보통 한 가지 관심사에 집중을 하며 보냅니다. 최근에서 온라인 부업이 관...        <아니다>
# 11599  <그렇다> 그렇습니다. 자주 걱정을 합니다. 인생을 살아오며 겪었던 경험이 영향을 ...        <그렇다>
# 11600  <그렇다> 지도자 역할을 싫어합니다. 왜냐하면 저는 대중 앞에 나서는 것을 싫어하기...        <그렇다>
# 11601  <그렇다> 예술적인 것들을 별로 좋아하지 않습니다. 그러한 것들을 보아도 어떠한 감...        <그렇다>
# 11602         <중립> 감정이 중요할 때도 있고 이성이 중요할 때도 있어 잘 모르겠습니다.         <중립>
# 11603  <그렇다> 저는 집안일을 다 끝내 놓고 휴식을 취합니다. 휴식을 취할 때 해야 하는...        <그렇다>
# 11604  <아니다> 다른 사람의 논쟁을 보는 것을 싫어합니다. 논쟁하는 것을 보고 있으면 마...        <아니다>
# 11605  <그렇다> 저는 다른 사람의 주의를 끌지 않으려고 합니다. 이유는 다른 사람이 저에...        <그렇다>
# 11606  <중립> 감정이 빠르게 변할 때도 있고 느리게 변할 때도 있습니다. 상황에 따라 다...         <중립>
# 11607  <그렇다> 짜증이 날 때도 있습니다. 어느 정도 효율적인 방법으로 일을 하지 못하면...        <그렇다>
# 11608  <아니다> 해야 할 일을 즉각적으로 하는 것을 좋아합니다. 최근에도 미루지 않고 하...        <아니다>
# 11609  <아니다> 저는 사후 세계에 대한 질문이 흥미롭지 않습니다. 이유는 사후 세계는 없...        <아니다>
# 11610    <아니다> 혼자서 있는 것을 좋아합니다. 요즘에는 그래서 모임에 나간 적이 없습니다.        <아니다>
# 11611  <중립> 제가 관심이 있는 분야라면 이론 중심의 토론이어도 흥미롭게 듣지만 관심이 ...         <중립>
# 11612        <중립> 잘 모르겠습니다. 공감을 할 때도 있고 못할 때도 있는 것 같습니다.         <중립>
# 11613  <그렇다> 결정을 내리는 일을 마지막까지 미루곤 합니다. 결정을 내리는 일을 어려워...        <그렇다>
# 11614  <아니다> 이미 내린 결정이라도 다시 자주 생각합니다. 잘못 내린 결정인지 아닌지 ...        <아니다>
# 11615       <아니다> 혼자 있는 것을 좋아하기 때문에 파티나 행사에 가는 것을 싫어합니다.        <아니다>
# 11616  <아니다> 저는 예술 작품 감상하는 것을 싫어합니다. 작가가 표현하고자 하는 것이 ...        <아니다>
# 11617        <아니다> 다른 사람의 감정에 공감이 잘 되는 편이기 때문에 힘들지 않습니다.        <아니다>
# 11618         <그렇다> 자기 전 그다음 날에 할 것을 미리 계획해 두는 것을 좋아합니다.        <그렇다>
# 11619  <아니다> 저는 불안감을 느낄 때가 많습니다. 인생을 살아오며 겪은 여러 경험에 의...        <아니다>
# 11620  <아니다> 전화 통화하는 것을 더 선호하는 편입니다. 의견 전달이 더 잘된다고 생각...        <아니다>
# 11621  <아니다> 다른 사람의 의견을 이해하는 데에 시간을 할애하지 않습니다. 그저 생각이...        <아니다>
# 11622  <아니다> 아닙니다. 저는 혼자서 있는 것을 좋아하기 때문에 친구에게 먼저 연락을 ...        <아니다>
# 11623  <아니다> 계획에 차질이 생기면 매우 당황해합니다. 한 달 수입에 맞춰 지출을 계산...        <아니다>
# 11624  <그렇다> 오래전의 실수를 후회할 때가 많습니다. 시아버지가 몇 년 전에 돈을 보태...        <그렇다>
# 11625  <아니다> 인간의 존재와 삶의 이유를 생각하지 않습니다. 인간도 결국 생물체라고 생...        <아니다>
# 11626  <그렇다> 감정에 잘 휘둘립니다. 주변에서도 어떤 때에는 이해가 안 될 정도로 감정...        <그렇다>
# 11627  <아니다> 저는 사실관계를 중요하게 생각합니다. 상대방의 잘못이라는 게 명백하다면 ...        <아니다>
# 11628  <아니다> 저는 계획에 따라 일관성 있는 업무를 하는 것을 좋아합니다. 달력에도 그...        <아니다>
# 11629  <아니다> 저는 상대방의 생각을 중요하게 생각하지 않습니다. 가장 중요한 건 자기 ...        <아니다>
# 11630  <그렇다> 혼자서 일할 수 있는 직업을 원합니다. 혼자서 생각하며 일하는 것이 재미...        <그렇다>
# 11631  <중립> 개인적으로는 철학적인 질문에 대해 생각을 하지 않지만 사람에 따라 다르기 ...         <중립>
# 11632  <아니다> 저는 혼자 있는 것을 좋아합니다. 사람들이 붐비고 떠들썩한 장소는 정신이...        <아니다>
# 11633  <아니다> 상대방의 감정을 잘 못 알아차릴 때가 많습니다. 그래서 눈치가 없다는 소...        <아니다>
# 11634         <아니다> 무엇인가에 압도 당하는 느낌을 느낀 적은 거의 없는 것 같습니다.        <아니다>
# 11635  <그렇다> 절차대로 일을 해나가는 것을 좋아합니다. 최근에 데이터 라벨링을 업무를 ...        <그렇다>
# 11636  <중립> 논란이 되거나 논쟁을 불러일으킬 수 있는 주제인지 와 상관없이 제 관심사인...         <중립>
# 11637  <아니다> 기회를 포기하지 않습니다. 다른 사람보다 제 자신이 제일 중요하다고 생각...        <아니다>
# 11638  <아니다> 마감 기한을 지키기 힘들지 않습니다. 저는 해야 하는 일이면 바로 하기 ...        <아니다>
# 11639  <아니다> 저는 일이 원하는 대로 진행될 것이라는 자신감이 떨어지는 편입니다. 살아...        <아니다>
#
#                                              Long_Answer
# 11580  저는 주기적으로는 새로운 친구들을 만들지 않습니다. 이유는 새로운 친구들을 사기기 ...
# 11581  자유 시간의 대부분을 관심사를 공부하는 데 씁니다. 요즘은 온라인 부업에 대해서 공...
# 11582  저는 다른 사람이 울고 있으면 같이 우는 편입니다. 울고 있는 사람의 슬픈 감정에 ...
# 11583   항상 여러 대비책을 세우는 편입니다. 이유는 계획과 달라졌을 때를 대비하기 위함입니다.
# 11584  저는 평정심을 유지하지 못합니다. 이유는 압박감이 없어도 스스로에게 엄격한 편이라 ...
# 11585  저는 저를 소개할 때도 있고 이미 알고 있는 사람과 이야기할 때도 있습니다. 보통 ...
# 11586  하나의 프로젝트를 완료하고 할 때도 있고 다른 프로젝트도 같이 할 때도 있습니다. ...
# 11587  저는 감상적이라고 생각합니다. 혼자 슬픈 생각이 자주 떠올라 우수에 젖을 때가 종종...
# 11588  계획을 세우는 일을 좋아합니다. 보통 핸드폰 앱을 이용하여 계획을 항상 세우는 편입니다.
# 11589  저는 작은 실수로도 제 능력을 의심합니다. 이유는 스스로에게 엄격하기 때문이며 최근...
# 11590  저는 관심이 가는 사람에게 다가가서 이야기를 먼저 거는 편입니다. 스스로가 인상이 ...
# 11591  예술 작품은 해석을 토론하는 일은 관심이 없습니다. 제가 관심이 있는 분야가 아니기...
# 11592  저는 이성에 따라서 판단하는 것을 선호하는 편입니다. 그러나 주변 사람들은 저를 감...
# 11593  계획을 세워하는 것을 좋아할 때도 있고 즉흥적으로 하는 것을 좋아할 때도 있습니다....
# 11594  다른 사람이 저를 어떻게 생각하는지 별로 신경 쓰지 않습니다. 20대에는 신경을 많...
# 11595  저는 단체 활동하는 것을 좋아하지 않습니다. 요즘에는 그래서 대부분의 시간을 혼자 ...
# 11596  저는 다양한 해석이 나올 수 있는 결말을 별로 좋아하지 않습니다. 명쾌한 결말이 나...
# 11597   제 자신이 더 중요하다고 생각합니다. 제 자신에게서 더 큰 만족감을 느끼기 때문입니다.
# 11598  보통 한 가지 관심사에 집중을 하며 보냅니다. 최근에서 온라인 부업이 관심사라 온라...
# 11599  그렇습니다. 자주 걱정을 합니다. 인생을 살아오며 겪었던 경험이 영향을 미친 것 같...
# 11600    지도자 역할을 싫어합니다. 왜냐하면 저는 대중 앞에 나서는 것을 싫어하기 때문입니다.
# 11601  예술적인 것들을 별로 좋아하지 않습니다. 그러한 것들을 보아도 어떠한 감흥이 잘 들...
# 11602              감정이 중요할 때도 있고 이성이 중요할 때도 있어 잘 모르겠습니다.
# 11603  저는 집안일을 다 끝내 놓고 휴식을 취합니다. 휴식을 취할 때 해야 하는 것이 있으...
# 11604  다른 사람의 논쟁을 보는 것을 싫어합니다. 논쟁하는 것을 보고 있으면 마음이 불편하...
# 11605  저는 다른 사람의 주의를 끌지 않으려고 합니다. 이유는 다른 사람이 저에 대해서 신...
# 11606  감정이 빠르게 변할 때도 있고 느리게 변할 때도 있습니다. 상황에 따라 다른 것 같...
# 11607  짜증이 날 때도 있습니다. 어느 정도 효율적인 방법으로 일을 하지 못하면 이해가 되...
# 11608    해야 할 일을 즉각적으로 하는 것을 좋아합니다. 최근에도 미루지 않고 하는 편입니다.
# 11609  저는 사후 세계에 대한 질문이 흥미롭지 않습니다. 이유는 사후 세계는 없다고 생각하...
# 11610          혼자서 있는 것을 좋아합니다. 요즘에는 그래서 모임에 나간 적이 없습니다.
# 11611  제가 관심이 있는 분야라면 이론 중심의 토론이어도 흥미롭게 듣지만 관심이 없는 분야...
# 11612             잘 모르겠습니다. 공감을 할 때도 있고 못할 때도 있는 것 같습니다.
# 11613  결정을 내리는 일을 마지막까지 미루곤 합니다. 결정을 내리는 일을 어려워하기 때문입니다.
# 11614  이미 내린 결정이라도 다시 자주 생각합니다. 잘못 내린 결정인지 아닌지 검토하기 위...
# 11615             혼자 있는 것을 좋아하기 때문에 파티나 행사에 가는 것을 싫어합니다.
# 11616  저는 예술 작품 감상하는 것을 싫어합니다. 작가가 표현하고자 하는 것이 이해가 안 ...
# 11617              다른 사람의 감정에 공감이 잘 되는 편이기 때문에 힘들지 않습니다.
# 11618               자기 전 그다음 날에 할 것을 미리 계획해 두는 것을 좋아합니다.
# 11619  저는 불안감을 느낄 때가 많습니다. 인생을 살아오며 겪은 여러 경험에 의해 불안감을...
# 11620  전화 통화하는 것을 더 선호하는 편입니다. 의견 전달이 더 잘된다고 생각하기 때문입니다.
# 11621  다른 사람의 의견을 이해하는 데에 시간을 할애하지 않습니다. 그저 생각이 다른 사람...
# 11622  아닙니다. 저는 혼자서 있는 것을 좋아하기 때문에 친구에게 먼저 연락을 잘하지 않습니다.
# 11623  계획에 차질이 생기면 매우 당황해합니다. 한 달 수입에 맞춰 지출을 계산해 놓았는데...
# 11624  오래전의 실수를 후회할 때가 많습니다. 시아버지가 몇 년 전에 돈을 보태주신 적이 ...
# 11625  인간의 존재와 삶의 이유를 생각하지 않습니다. 인간도 결국 생물체라고 생각하기 때문...
# 11626  감정에 잘 휘둘립니다. 주변에서도 어떤 때에는 이해가 안 될 정도로 감정에 휘둘린다...
# 11627  저는 사실관계를 중요하게 생각합니다. 상대방의 잘못이라는 게 명백하다면 굳이 체면을...
# 11628  저는 계획에 따라 일관성 있는 업무를 하는 것을 좋아합니다. 달력에도 그 달의 계획...
# 11629  저는 상대방의 생각을 중요하게 생각하지 않습니다. 가장 중요한 건 자기 자신이라고 ...
# 11630  혼자서 일할 수 있는 직업을 원합니다. 혼자서 생각하며 일하는 것이 재미있기 때문입니다.
# 11631  개인적으로는 철학적인 질문에 대해 생각을 하지 않지만 사람에 따라 다르기 때문에 철...
# 11632  저는 혼자 있는 것을 좋아합니다. 사람들이 붐비고 떠들썩한 장소는 정신이 없어 보통...
# 11633  상대방의 감정을 잘 못 알아차릴 때가 많습니다. 그래서 눈치가 없다는 소리를 들은 ...
# 11634               무엇인가에 압도 당하는 느낌을 느낀 적은 거의 없는 것 같습니다.
# 11635  절차대로 일을 해나가는 것을 좋아합니다. 최근에 데이터 라벨링을 업무를 하기 위해 ...
# 11636  논란이 되거나 논쟁을 불러일으킬 수 있는 주제인지 와 상관없이 제 관심사인지 아닌지...
# 11637  기회를 포기하지 않습니다. 다른 사람보다 제 자신이 제일 중요하다고 생각하기 때문입니다.
# 11638  마감 기한을 지키기 힘들지 않습니다. 저는 해야 하는 일이면 바로 하기 때문에 기한...
# 11639  저는 일이 원하는 대로 진행될 것이라는 자신감이 떨어지는 편입니다. 살아오면서 일이...
